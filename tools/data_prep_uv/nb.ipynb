# %%
import pandas as pd

df = pd.read_parquet(r"/quant/nifty_with_options_01Jan2023_06Mar2026.parquet")


print(df.head())
# Out:
#                 Ticker      Open      High       Low     Close  \
# 0             NIFTY 50  18131.70  18153.20  18117.05  18141.35
# 1  NIFTY02FEB2317500PE     98.10     98.10     98.10     98.10
# 2  NIFTY02FEB2318000CE    525.15    525.85    453.10    453.10
# 3  NIFTY05JAN2315050PE      0.60      0.60      0.50      0.50
# 4  NIFTY05JAN2315100PE      0.50      0.55      0.40      0.40
#
#                   timestamp
# 0 2023-01-02 09:16:00+05:30
# 1 2023-01-02 09:16:00+05:30
# 2 2023-01-02 09:16:00+05:30
# 3 2023-01-02 09:16:00+05:30
# 4 2023-01-02 09:16:00+05:30
